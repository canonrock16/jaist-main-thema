# %%
import pickle
import seaborn as sns

# %% [markdown]
# # W

# %% [markdown]
# # 0.0

# %%
# with open('./results/pickle/w.pkl','rb') as f:
# with open('./results/pickle/2022–03–06_2301/w_Ce_0.0.pkl','rb') as f:
with open('./results/pickle/2022–03–09_2240/w_Ce_0.0.pkl','rb') as f:
    hoge = pickle.load(f)
sns.distplot(hoge)
sns.set()
# Out:
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# with open('./results/pickle/w.pkl','rb') as f:
# with open('./results/pickle/2022–03–06_2301/w_Ce_0.0.pkl','rb') as f:
with open('./results/pickle/2022–03–09_2240/w_Ce_0.0.pkl','rb') as f:
    hoge = pickle.load(f)
sns.distplot(hoge)
sns.set()
# Out:
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# with open('./results/pickle/w.pkl','rb') as f:
with open('./results/pickle/2022–03–06_2301/w_Ci_0.0.pkl','rb') as f:
    hoge = pickle.load(f)
sns.distplot(hoge)
sns.set()
# Out:
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 0.5

# %%
# with open('./results/pickle/w.pkl','rb') as f:
with open('./results/pickle/2022–03–06_2301/w_Ce_0.5.pkl','rb') as f:
    hoge = pickle.load(f)
sns.distplot(hoge)
sns.set()
# Out:
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# with open('./results/pickle/w.pkl','rb') as f:
with open('./results/pickle/2022–03–06_2301/w_Ci_0.5.pkl','rb') as f:
    hoge = pickle.load(f)
sns.distplot(hoge)
sns.set()
# Out:
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 1.0

# %%
# with open('./results/pickle/w.pkl','rb') as f:
with open('./results/pickle/2022–03–06_2301/w_Ce_1.0.pkl','rb') as f:
    hoge = pickle.load(f)
sns.distplot(hoge)
sns.set()
# Out:
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# with open('./results/pickle/w.pkl','rb') as f:
with open('./results/pickle/2022–03–06_2301/w_Ci_1.0.pkl','rb') as f:
    hoge = pickle.load(f)
sns.distplot(hoge)
sns.set()
# Out:
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
# with open('./results/pickle/w.pkl','rb') as f:
# with open('./results/pickle/2022–03–06_2301/w_Ce_1.0.pkl','rb') as f:
with open('./results/pickle/2022–03–09_2300/w_Ce_1.0.pkl','rb') as f:
    hoge = pickle.load(f)
sns.distplot(hoge)
sns.set()
# Out:
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# with open('./results/pickle/w.pkl','rb') as f:
# with open('./results/pickle/2022–03–06_2301/w_Ci_1.0.pkl','rb') as f:
with open('./results/pickle/2022–03–09_2300/w_Ci_1.0.pkl','rb') as f:
    hoge = pickle.load(f)
sns.distplot(hoge)
sns.set()
# Out:
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/s2030415/.cache/pypoetry/virtualenvs/jaist-main-thema-H2Y42tMi-py3.8/lib/python3.8/site-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # spikes

# %%
with open('results/pickle/2022–03–06_2301/spikes_0.0.pkl','rb') as f:
    hoge = pickle.load(f)

# %%
len(hoge)
# Out:
# 100000

# %%
int(rand*2000)/100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 int(rand*2000)/100
#
# NameError: name 'rand' is not defined

# %%
import random
# Out:
# 0.12294565238868083

# %%
random.uniform(0,20)
# Out:
# 8.499327746525257

# %%
import numpy as np

# %%
v = np.fromfile('output_1.0/results/_dynamic_array_statemonitor_v_6391599931923040010')

# %%
v.shape
# Out:
# (10000000000,)

# %%
v
# Out:
# array([-0.08881252, -0.05617683, -0.11473869, ..., -0.065     ,
#         0.22259759, -0.065     ])

# %%
with open('./results/pickle/2022–03–15_2336/v_1.0.pkl','rb') as f:
    hoge = pickle.load(f)

# %%
hoge
# Out:
# array([[-0.07144004, -0.07140535, -0.07137142, -0.07133823, -0.07130577,
#         -0.07127402, -0.07124298, -0.07121262, -0.07118295, -0.07115393],
#        [-0.07010187, -0.07009915, -0.0700965 , -0.07009391, -0.0700914 ,
#         -0.07008896, -0.07008657, -0.07008426, -0.070082  , -0.07007981],
#        [-0.0711416 , -0.07111352, -0.07108608, -0.07105925, -0.07103304,
#         -0.07100743, -0.0649824 , -0.06758951, -0.06941498, -0.07036131],
#        [-0.07700978, -0.07687933, -0.07675077, -0.07662408, -0.07649924,
#         -0.07637625, -0.07625507, -0.07613571, -0.07601813, -0.07590232],
#        [-0.07009277, -0.07009029, -0.07008788, -0.07008552, -0.07008323,
#         -0.070081  , -0.07007884, -0.07007672, -0.07007467, -0.07007267],
#        [-0.06632135, -0.06802486, -0.06910548, -0.06966864, -0.06992393,
#         -0.07003031, -0.07007214, -0.07008738, -0.07009192, -0.07009221],
#        [-0.07784885, -0.07783144, -0.07166088, -0.07736461, -0.07744409,
# ...
